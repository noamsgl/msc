# %% [markdown]
# # Explore seizure occurrences
# Noam Siegel, Ben Gurion University

# %%
from msc.canine_db_utils import get_onsets
from msc.plot_utils import plot_seizure_occurrences_timeline
from msc.plot_utils import plot_seizure_intervals_histogram

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
onsets_1 = get_onsets(dog_num=1)
onsets_2 = get_onsets(dog_num=2)
onsets_3 = get_onsets(dog_num=3)

# %% [markdown]
# ## Seizure occurrences - Dog 1

# %%
plot_seizure_occurrences_timeline(onsets_1, f"Dog 1")

# %% [markdown]
# ## Seizure intervals - Dog 1

# %%
plot_seizure_intervals_histogram(onsets_1, "Dog 1")

# %% [markdown]
# ## Seizure occurrences - Dog 2

# %%
plot_seizure_occurrences_timeline(onsets_2, f"Dog 2")

# %% [markdown]
# ## Seizure intervals - Dog 2

# %%
plot_seizure_intervals_histogram(onsets_2, "Dog 2")

# %% [markdown]
# ## Seizure occurrences - Dog 3

# %%
plot_seizure_occurrences_timeline(onsets_3, f"Dog 3")

# %% [markdown]
# ## Seizure intervals - Dog 3

# %%
plot_seizure_intervals_histogram(onsets_3, "Dog 3")
