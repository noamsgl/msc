# %% [markdown]
# ## Dataset Exploration Plots

# %%
# %load_ext autoreload
# %autoreload 2

from scripts.pp.explore.plot_seizure_occurrences_timeline import plot_seizure_occurrences_timeline
from msc.dataset.dataset import get_seizures_index_df, get_data_index_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# this method relies on the config file
seizures_index_df = get_seizures_index_df()

selected_patient = 'pat_3500'
plot_seizure_occurrences_timeline(selected_patient, seizures_index_df)

# %%
selected_patient = 'pat_3700'
plot_seizure_occurrences_timeline(selected_patient, seizures_index_df)

# %%
selected_patient = 'pat_7200'
plot_seizure_occurrences_timeline(selected_patient, seizures_index_df)

# %%
selected_patient = 'pat_2200'
plot_seizure_occurrences_timeline(selected_patient, seizures_index_df)

# %%
selected_patient = 'pat_1326003'
plot_seizure_occurrences_timeline(selected_patient, seizures_index_df)
