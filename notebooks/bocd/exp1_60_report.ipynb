# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import mne

# %% [markdown]
# # M.Sc. Experiment Report
#
# ## Abstract
#
# * We hypothesize that a variant of BOCD might be able to segment EEG data into neurotypical brain states related to epilepsy neurodynamics.
# * To this end, we apply BOCD to raw EEG.
# * As a proof of concept, we apply the algorithm to 30 seconds, non-seizure EEG, on each channel separately.
# * Further tasks include running BOCD on seizure data.
#
#
# ## Introduction
# Todo
#
# ## Method
# ### Data
# * Dataset: EPILEPSIAE (patient 800)
# * File: `8010200_0006.data`
# * Times: [0, 60sec]
#
# ### Procedure
# We selected a 60-second segment of (awake/seizure?) EEG data.
# We applied Bayesian Online Changepoint Detection on this data for each channel separately.
#
# ### Instructions
# Run the following command:
#
# ```commandline
# python scripts/run_BOCD_on_EEG.py
# ```
#
# ## Results and Discussion
# We present graphically the results of BOCD on raw EEG.
#
# * The changepoints, when detected, are always located at positions where the signal changes sign.
#
#
# ## References
# [D. Tolpin's BOCD implementation on GitHub](https://github.com/dtolpin/bocd)

# %%
# %matplotlib inline
exp_path = r"C:\Users\noam\Repositories\noamsgl\msc\output\exp1\60"
images = []
for img_path in glob.glob(exp_path + '\\*\\*.png'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(30,200))
columns = 2
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i+1)
    plt.imshow(image)
# Out:
# c:\users\noam\envs\tvb\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   # Remove the CWD from sys.path while we load stuff.
