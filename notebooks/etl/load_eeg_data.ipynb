# %% [markdown]
# # Imports

# %%
import os.path

import numpy as np
import mne
import matplotlib
import msc

# %matplotlib qt

# %% [markdown]
# # Load Data

# %%
fpath = r'C:\temp\surf30\pat_103002\adm_1030102\rec_103001102\103001102_0113.data'
# fpath = r'C:\Users\noam\Repositories\noamsgl\msc\input\raw_eeg\8010200_0006.data'
# fpath = r'C:\Users\noam\Repositories\noamsgl\msc\input\tuh\isip.piconepress.com\projects\tuh_eeg\downloads\tuh_eeg\v1.2.0\edf\01_tcp_ar\000\00000015\s003_2015_12_28\00000015_s003_t000.edf'

raw = msc.etl.load(fpath)
print(raw)
# Out:
# Reading header...
# <RawNicolet | 103001102_0113.data, 37 x 103936 (406.0 s), ~41 kB, data not loaded>

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 1605x919 with 4 Axes>

# %%
raw.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, T5, ...
#  chs: 37 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: 2008-07-13 08:07:34 UTC
#  nchan: 37
#  projs: []
#  sfreq: 256.0 Hz
# >

# %%
raw.to_data_frame()
# Out:
#           time     FP1      FP2      F3       F4      C3      C4      P3  \
# 0            0 -54.595 -227.867 -66.230 -259.013 -97.913  -2.148 -22.912
# 1            4 -81.445 -220.707 -45.287 -258.118 -91.111   1.432 -22.554
# 2            8 -87.710 -219.454 -34.905 -257.402 -81.803   6.802 -10.561
# 3           12 -55.669 -214.979 -54.595 -252.748 -79.655  12.351 -10.203
# 4           16 -80.371 -201.912 -47.972 -246.841 -73.748  15.931  -7.339
# ...        ...     ...      ...     ...      ...     ...     ...     ...
# 103931  405980 -47.793 -209.788 -79.834 -254.359 -83.414   5.907 -14.141
# 103932  405984 -44.750 -203.702 -53.163 -239.502 -74.285  16.647  -2.148
# 103933  405988 -50.299 -212.115 -44.929 -242.545 -78.223  13.962  -5.907
# 103934  405992 -49.046 -211.220 -61.218 -250.063 -88.784  11.635 -14.857
# 103935  405996 -61.576 -218.917 -69.094 -254.359 -94.333   5.191 -16.826
#
#              P4       O1  ...       ECG  PHO      CP1      CP2      CP5  \
# ...
