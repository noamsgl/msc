# %%
import pandas as pd

import matplotlib.pyplot as plt
from msc import config
from msc.dataset import UniformDataset
import seaborn as sns
sns.set_theme(style="white")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load dataset info

# %%
dataset_dir = r"C:\Users\noam\Repositories\noamsgl\msc\results\epilepsiae\UNIFORM\20220106T165558"
dataset = UniformDataset(dataset_dir)
samples_df = dataset.samples_df
samples_df
# Out:
# loading
# done loading
# ...
#      index  patient_name                                    window_interval  \
# 0      0.0           NaN  [Timestamp('2008-11-05 23:44:50.105065'),Times...
# 1      1.0           NaN  [Timestamp('2008-09-04 12:25:16.801598'),Times...
# 2      2.0           NaN  [Timestamp('2008-06-07 03:53:32.359954'),Times...
# 3      3.0           NaN  [Timestamp('2008-07-06 12:36:55.567208'),Times...
# 4      4.0           NaN  [Timestamp('2004-02-22 03:04:55.766070'),Times...
# ..     ...           ...                                                ...
# 995  995.0           NaN  [Timestamp('2008-05-09 08:37:44.578676'),Times...
# 996  996.0           NaN  [Timestamp('2008-05-19 11:29:03.260274'),Times...
# 997  997.0           NaN  [Timestamp('2004-07-23 06:33:21.771004'),Times...
# 998  998.0           NaN  [Timestamp('2008-05-03 21:02:49.958375'),Times...
# 999  999.0           NaN  [Timestamp('2008-06-06 16:11:32.238568'),Times...
#
# ...

# %% [markdown]
# ## Load GP Maximum Likelihood Estimation Results

# %%
# uniform_results_df = pd.read_csv(r"C:\Users\noam\Repositories\noamsgl\msc\results\params\results_uniform_20220112T012831.csv")
uniform_results_df = pd.read_csv(r"C:\Users\noam\Repositories\noamsgl\msc\results\params\results_1000.csv")

uniform_results_df = uniform_results_df.pivot(index='sample_id', columns='param_name', values='param_value').join(samples_df, on='sample_id')
uniform_results_df
# Out:
#            covar_module.base_kernel.raw_lengthscale  \
# sample_id
# 0                                          0.478211
# 1                                          0.477431
# 2                                          0.478178
# 3                                          0.476830
# 4                                          0.475036
# ...                                             ...
# 995                                       -0.444950
# 996                                       -0.432197
# 997                                        0.481659
# 998                                       -0.471351
# 999                                        0.176056
#
#            covar_module.raw_outputscale  likelihood.noise_covar.raw_noise  \
# sample_id
# 0                             -0.488561                         -1.011795
# 1                             -0.492144                         -1.514724
# 2                             -0.490924                         -2.017304
# ...

# %%
# seizures_results_df = pd.read_csv(r"C:\Users\noam\Repositories\noamsgl\msc\results\params\results_seizures_20220112T032239.csv")
seizures_results_df = pd.read_csv(r"C:\Users\noam\Repositories\noamsgl\msc\results\params\results_seizure_20220109T193139.csv")
seizures_results_df = seizures_results_df.pivot(index='sample_id', columns='param_name', values='param_value').join(samples_df, on='sample_id')
seizures_results_df
# Out:
#            covar_module.base_kernel.raw_lengthscale  \
# sample_id
# 0                                          0.467654
# 1                                          0.477307
# 2                                         -0.456080
# 3                                         -0.464846
# 4                                          0.482202
# ...                                             ...
# 1178                                       0.448448
# 1179                                      -0.255313
# 1180                                       0.469320
# 1181                                      -0.374430
# 1182                                      -0.380224
#
#            covar_module.raw_outputscale  likelihood.noise_covar.raw_noise  \
# sample_id
# 0                              0.449511                         -0.506070
# 1                              0.389437                         -1.010462
# 2                              0.450585                         -0.571344
# ...

# %%
# concat
results_df = pd.concat([uniform_results_df, seizures_results_df], keys=('uniform', 'seizures')).rename_axis(['dataset', 'sample_id']).reset_index()

# %% [markdown]
# ## Plot GP MLE Results

# %%
results_df
# Out:
#        dataset  sample_id  covar_module.base_kernel.raw_lengthscale  \
# 0      uniform          0                                  0.478211
# 1      uniform          1                                  0.477431
# 2      uniform          2                                  0.478178
# 3      uniform          3                                  0.476830
# 4      uniform          4                                  0.475036
# ...        ...        ...                                       ...
# 2178  seizures       1178                                  0.448448
# 2179  seizures       1179                                 -0.255313
# 2180  seizures       1180                                  0.469320
# 2181  seizures       1181                                 -0.374430
# 2182  seizures       1182                                 -0.380224
#
#       covar_module.raw_outputscale  likelihood.noise_covar.raw_noise  index  \
# ...

# %%
params_to_plot = ["covar_module.base_kernel.raw_lengthscale",
                  "covar_module.raw_outputscale",
#                   "likelihood.noise_covar.raw_noise"
                 ]
id_vars = results_df.columns.difference(params_to_plot)
melted = results_df.melt(id_vars=id_vars, var_name="param_name")
g = sns.FacetGrid(data=melted, row='param_name', col='dataset', sharex=False, sharey=False, hue='dataset', height=4).map(sns.histplot, 'value',bins=100)
g.set_titles("{col_name}\n{row_name}", size=14)
g.fig.tight_layout()

# %%
def plot_param_results(results_df, dataset, params_to_plot) -> None:
    for param_name in params_to_plot:
        # plot output scale distribution
        results_df.groupby('dataset').get_group(dataset)[param_name].plot(kind='hist', bins=100, title=param_name)
        plt.show()
    return None

dataset = "uniform"
plot_param_results(results_df, dataset, params_to_plot)

# %%
sns.jointplot(data=results_df,
            x="covar_module.base_kernel.raw_lengthscale",
            y="covar_module.raw_outputscale",
            hue="dataset", palette="muted", )

# %%
sns.jointplot(data=results_df,
            x="covar_module.base_kernel.raw_lengthscale",
            y="covar_module.raw_outputscale",
            hue="lowpass", palette="muted")

# %% [markdown]
# ## Playground

# %%
import numpy as np
data1 = {"X": np.linspace(0,1,30), "Y": np.sin(np.linspace(0,1,30)), "ds": "d1"}
df1 = pd.DataFrame(data1) 
data2 = {"X": np.linspace(0,1,20), "Y": np.sin(np.linspace(0,1,20)), "ds":"d2"}
df2 = pd.DataFrame(data2)
df = pd.concat([df1, df2]).reset_index(drop=True)
df
sns.jointplot(data=df, x="X", y="Y", hue="ds")

# %% [markdown]
# ## Add Seizure results

# %%
seizures_results_df = pd.read_csv('results_seizure_20220109T193139.csv').pivot(index='sample_id', columns='param_name', values='param_value')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37876/3280856858.py in <module>
# ----> 1 seizures_results_df = pd.read_csv('results_seizure_20220109T193139.csv').pivot(index='sample_id', columns='param_name', values='param_value')
#
# ~\.virtualenvs\msc-WSmVxSSb\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
results_df = pd.concat([results_df, seizures_results_df], keys=('uniform', 'seizure')).reset_index(level=1, drop=True).rename_axis('dataset').reset_index()

# %% [markdown]
# ## Plot Uniform and some of Seizures Results

# %%
sns.jointplot(data=results_df,
            x="covar_module.base_kernel.raw_lengthscale",
            y="covar_module.raw_outputscale",
            hue="dataset", palette="muted", xlim=(-1,1), ylim=(-1,1))
