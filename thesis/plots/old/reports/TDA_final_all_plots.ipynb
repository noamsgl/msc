# %% [markdown]
# ## Evaluate ictality alerting
# Noam Siegel, Ben Gurion University

# %%
# imports
import matplotlib.pyplot as plt
plt.style.use('science')
import numpy as np
import pandas as pd
import seaborn as sns
from pytorch_lightning import seed_everything
from sklearn import mixture
from sklearn.metrics import RocCurveDisplay

from msc.plot_utils import add_tsne_to_df
from msc.results_collectors import GPResultsCollector

seed_everything(42)
# %load_ext autoreload
# %autoreload 2
# Out:
# Global seed set to 42
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
figs_base_dir = r"C:\Users\noam\Dropbox\Apps\Overleaf\MScThesis\5Results\figs"

# %% [markdown]
# ## Load all embeddings
# version 0.1.0
# from CSV

# %%
results_fpath = r"C:\Users\noam\Repositories\noamsgl\msc\results\results-21-2-22\results.csv"
results_df = pd.read_csv(results_fpath, index_col=0)

# %% [markdown]
# ## Drop Nans

# %%
results_df = results_df.dropna(subset=['train_loss'])

# %% [markdown]
# ## Add test answer keys

# %%
# load answer keys
test_answer_key_fpath = r"C:\Users\noam\Repositories\noamsgl\msc\data\seizure-detection\SzDetectionAnswerKey.csv"
test_labels = pd.read_csv(test_answer_key_fpath)
test_labels['clip_name'] = test_labels['clip'].apply(lambda fname: fname[:-4])
# add answer keys to results
results_df = pd.merge(results_df, test_labels, how='left',on="clip_name")

# %%
results_df
# Out:
#        train_loss  likelihood.raw_task_noises[0]  \
# 0       -0.366232                      -6.322467
# 1       -0.289474                            NaN
# 2       -0.430646                            NaN
# 3       -0.311700                      -6.604381
# 4       -0.393655                            NaN
# ...           ...                            ...
# 41003   -0.748452                            NaN
# 41004   -0.842039                            NaN
# 41005   -0.717861                            NaN
# 41006   -0.599081                            NaN
# 41007   -0.730661                            NaN
#
#        likelihood.raw_task_noises[1]  likelihood.raw_noise  \
# 0                          -6.429121             -6.381074
# 1                                NaN             -6.351304
# 2                                NaN             -6.359039
# 3                          -6.209981             -6.452849
# 4                                NaN             -6.485181
# ...                              ...                   ...
# 41003                            NaN             -7.305155
# 41004                            NaN             -7.000558
# 41005                            NaN             -7.029493
# 41006                            NaN             -7.075176
# 41007                            NaN             -7.358281
#
#        covar_module.task_covar_module.covar_factor[0]  \
# 0                                            0.346284
# 1                                                 NaN
# 2                                                 NaN
# 3                                            0.468721
# 4                                                 NaN
# ...                                               ...
# 41003                                             NaN
# 41004                                             NaN
# 41005                                             NaN
# 41006                                             NaN
# 41007                                             NaN
#
#        covar_module.task_covar_module.covar_factor[1]  \
# 0                                            0.365560
# 1                                                 NaN
# 2                                                 NaN
# 3                                            0.572521
# 4                                                 NaN
# ...                                               ...
# 41003                                             NaN
# 41004                                             NaN
# 41005                                             NaN
# 41006                                             NaN
# 41007                                             NaN
#
#        covar_module.task_covar_module.raw_var[0]  \
# 0                                      -0.452325
# 1                                            NaN
# 2                                            NaN
# 3                                      -0.986530
# 4                                            NaN
# ...                                          ...
# 41003                                        NaN
# 41004                                        NaN
# 41005                                        NaN
# 41006                                        NaN
# 41007                                        NaN
#
#        covar_module.task_covar_module.raw_var[1]  \
# 0                                      -1.079334
# 1                                            NaN
# 2                                            NaN
# 3                                      -0.482866
# 4                                            NaN
# ...                                          ...
# 41003                                        NaN
# 41004                                        NaN
# 41005                                        NaN
# 41006                                        NaN
# 41007                                        NaN
#
#        covar_module.data_covar_module.raw_lengthscale  epoch  ...  \
# 0                                           -4.181092  999.0  ...
# 1                                           -4.189489  999.0  ...
# 2                                           -4.094140  999.0  ...
# 3                                           -4.171540  999.0  ...
# 4                                           -3.985386  999.0  ...
# ...                                               ...    ...  ...
# 41003                                       -3.984214  999.0  ...
# 41004                                       -4.172774  999.0  ...
# 41005                                       -3.685556  999.0  ...
# 41006                                       -4.087623  999.0  ...
# 41007                                       -3.936868  999.0  ...
#
#                      clip_name label_desc version num_channels  \
# 0        Dog_1_ictal_segment_1      ictal   0.1.0            2
# 1        Dog_1_ictal_segment_1      ictal   0.1.0            1
# 2        Dog_1_ictal_segment_1      ictal   0.1.0            1
# 3        Dog_1_ictal_segment_1      ictal   0.1.0            2
# 4        Dog_1_ictal_segment_1      ictal   0.1.0            1
# ...                        ...        ...     ...          ...
# 41003  Dog_1_test_segment_2075       test   0.1.0            1
# 41004  Dog_1_test_segment_2075       test   0.1.0            1
# 41005  Dog_1_test_segment_2075       test   0.1.0            1
# 41006  Dog_1_test_segment_2075       test   0.1.0            1
# 41007  Dog_1_test_segment_2075       test   0.1.0            1
#
#       likelihood.raw_task_noises  covar_module.task_covar_module.covar_factor  \
# 0                            NaN                                          NaN
# 1                      -6.351304                                     0.206774
# 2                      -6.359039                                     0.111852
# 3                            NaN                                          NaN
# 4                      -6.485181                                     0.316019
# ...                          ...                                          ...
# 41003                  -7.305155                                     0.020434
# 41004                  -7.000558                                     0.000057
# 41005                  -7.029493                                     0.341225
# 41006                  -7.075176                                     0.091386
# 41007                  -7.358281                                     0.131919
#
#        covar_module.task_covar_module.raw_var                         clip  \
# 0                                         NaN                          NaN
# 1                                   -0.281881                          NaN
# 2                                   -0.456813                          NaN
# 3                                         NaN                          NaN
# 4                                   -0.084873                          NaN
# ...                                       ...                          ...
# 41003                               -0.698031  Dog_1_test_segment_2075.mat
# 41004                               -1.809473  Dog_1_test_segment_2075.mat
# 41005                               -0.201487  Dog_1_test_segment_2075.mat
# 41006                               -0.621841  Dog_1_test_segment_2075.mat
# 41007                               -0.521822  Dog_1_test_segment_2075.mat
#
#        seizure early
# 0          NaN   NaN
# 1          NaN   NaN
# 2          NaN   NaN
# 3          NaN   NaN
# 4          NaN   NaN
# ...        ...   ...
# 41003     -1.0   0.0
# 41004     -1.0   0.0
# 41005     -1.0   0.0
# 41006     -1.0   0.0
# 41007     -1.0   0.0
#
# [41008 rows x 22 columns]

# %%
results_df.columns,
# Out:
# (Index(['train_loss', 'likelihood.raw_task_noises[0]',
#         'likelihood.raw_task_noises[1]', 'likelihood.raw_noise',
#         'covar_module.task_covar_module.covar_factor[0]',
#         'covar_module.task_covar_module.covar_factor[1]',
#         'covar_module.task_covar_module.raw_var[0]',
#         'covar_module.task_covar_module.raw_var[1]',
#         'covar_module.data_covar_module.raw_lengthscale', 'epoch', 'step',
#         'ch_names', 'clip_name', 'label_desc', 'version', 'num_channels',
#         'likelihood.raw_task_noises',
#         'covar_module.task_covar_module.covar_factor',
#         'covar_module.task_covar_module.raw_var', 'clip', 'seizure', 'early'],
#        dtype='object'),)

# %%
single_channel_params = ['covar_module.data_covar_module.raw_lengthscale',
                         'covar_module.task_covar_module.covar_factor', 'covar_module.task_covar_module.raw_var']
double_channel_params = ['covar_module.task_covar_module.covar_factor[0]',
                         'covar_module.task_covar_module.covar_factor[1]',
                         'covar_module.task_covar_module.raw_var[0]',
                         'covar_module.task_covar_module.raw_var[1]',
                         'covar_module.data_covar_module.raw_lengthscale']

# %%
single_results_df = results_df.loc[results_df['num_channels'] == 1, single_channel_params + ['label_desc'] + ['clip_name'] + ['seizure']]
single_results_df
# Out:
#        covar_module.data_covar_module.raw_lengthscale  \
# 1                                           -4.189489
# 2                                           -4.094140
# 4                                           -3.985386
# 5                                           -4.239130
# 7                                           -4.159550
# ...                                               ...
# 41003                                       -3.984214
# 41004                                       -4.172774
# 41005                                       -3.685556
# 41006                                       -4.087623
# 41007                                       -3.936868
#
#        covar_module.task_covar_module.covar_factor  \
# 1                                         0.206774
# 2                                         0.111852
# 4                                         0.316019
# 5                                         0.332558
# 7                                         0.163072
# ...                                            ...
# 41003                                     0.020434
# 41004                                     0.000057
# 41005                                     0.341225
# 41006                                     0.091386
# 41007                                     0.131919
#
#        covar_module.task_covar_module.raw_var label_desc  \
# 1                                   -0.281881      ictal
# 2                                   -0.456813      ictal
# 4                                   -0.084873      ictal
# 5                                   -0.212837      ictal
# 7                                   -0.399358      ictal
# ...                                       ...        ...
# 41003                               -0.698031       test
# 41004                               -1.809473       test
# 41005                               -0.201487       test
# 41006                               -0.621841       test
# 41007                               -0.521822       test
#
#                      clip_name  seizure
# 1        Dog_1_ictal_segment_1      NaN
# 2        Dog_1_ictal_segment_1      NaN
# 4        Dog_1_ictal_segment_1      NaN
# 5        Dog_1_ictal_segment_1      NaN
# 7        Dog_1_ictal_segment_1      NaN
# ...                        ...      ...
# 41003  Dog_1_test_segment_2075     -1.0
# 41004  Dog_1_test_segment_2075     -1.0
# 41005  Dog_1_test_segment_2075     -1.0
# 41006  Dog_1_test_segment_2075     -1.0
# 41007  Dog_1_test_segment_2075     -1.0
#
# [28128 rows x 6 columns]

# %%
double_results_df = results_df.loc[results_df['num_channels'] == 2, double_channel_params + ['label_desc'] + ['clip_name'] + ['seizure']]
double_results_df
# Out:
#        covar_module.task_covar_module.covar_factor[0]  \
# 0                                            0.346284
# 3                                            0.468721
# 6                                            0.533905
# 9                                            0.667333
# 11                                          -0.051277
# ...                                               ...
# 38071                                       -0.073962
# 38074                                        0.163001
# 38077                                        0.038648
# 38080                                        0.248586
# 38083                                       -0.205528
#
#        covar_module.task_covar_module.covar_factor[1]  \
# 0                                            0.365560
# 3                                            0.572521
# 6                                            0.628705
# 9                                            0.301694
# 11                                           0.348626
# ...                                               ...
# 38071                                       -0.118927
# 38074                                        0.178441
# 38077                                        0.208553
# 38080                                        0.044722
# 38083                                       -0.094457
#
#        covar_module.task_covar_module.raw_var[0]  \
# 0                                      -0.452325
# 3                                      -0.986530
# 6                                      -2.208740
# 9                                       0.939679
# 11                                      1.393423
# ...                                          ...
# 38071                                  -3.461426
# 38074                                  -3.272478
# 38077                                  -3.053872
# 38080                                  -2.145833
# 38083                                  -2.722822
#
#        covar_module.task_covar_module.raw_var[1]  \
# 0                                      -1.079334
# 3                                      -0.482866
# 6                                      -1.927185
# 9                                      -0.839994
# 11                                      0.907051
# ...                                          ...
# 38071                                  -3.277023
# 38074                                  -3.830204
# 38077                                  -3.090405
# 38080                                  -2.694724
# 38083                                  -2.565971
#
#        covar_module.data_covar_module.raw_lengthscale label_desc  \
# 0                                           -4.181092      ictal
# 3                                           -4.171540      ictal
# 6                                           -4.388024      ictal
# 9                                           -4.190533      ictal
# 11                                          -3.915130      ictal
# ...                                               ...        ...
# 38071                                       -4.660611       test
# 38074                                       -4.725718       test
# 38077                                       -4.894453       test
# 38080                                       -4.851481       test
# 38083                                       -4.525832       test
#
#                      clip_name  seizure
# 0        Dog_1_ictal_segment_1      NaN
# 3        Dog_1_ictal_segment_1      NaN
# 6        Dog_1_ictal_segment_1      NaN
# 9        Dog_1_ictal_segment_1      NaN
# 11       Dog_1_ictal_segment_1      NaN
# ...                        ...      ...
# 38071  Dog_1_test_segment_1910     -1.0
# 38074  Dog_1_test_segment_1910     -1.0
# 38077  Dog_1_test_segment_1910     -1.0
# 38080  Dog_1_test_segment_1910     -1.0
# 38083  Dog_1_test_segment_1911     -1.0
#
# [12880 rows x 8 columns]

# %%
# single_results_df = add_tsne_to_df(single_results_df, single_channel_params)

# %% [markdown]
# ## Estimate interictal embeddings density

# %%
# fit a Gaussian Mixture Model with two components to the interictal training clips
gmm = mixture.GaussianMixture(n_components=2, covariance_type="full")
gmm.fit(single_results_df.loc[single_results_df['label_desc'] == 'interictal', single_channel_params].values)
# Out:
# GaussianMixture(n_components=2)

# %%
# compute negative log likelihood (novelty score) for all clips
single_results_df["nll"] = single_results_df.apply(lambda row: -gmm.score(np.array(row[single_channel_params]).reshape(1, -1)), axis=1)

# %%
# compute p_values for all clips
interictals = single_results_df.loc[single_results_df['label_desc'] == 'interictal']
single_results_df['p_value'] = single_results_df.apply(
    lambda row: (len(interictals.loc[interictals["nll"] < row['nll']])) / len(interictals), axis=1)

# %%
# fit a Gaussian Mixture Model with two components to the interictal training clips
gmm = mixture.GaussianMixture(n_components=2, covariance_type="full")
gmm.fit(double_results_df.loc[double_results_df['label_desc'] == 'interictal', double_channel_params].values)
# Out:
# GaussianMixture(n_components=2)

# %%
# compute negative log likelihood (novelty score) for all clips
double_results_df["nll"] = double_results_df.apply(lambda row: -gmm.score(np.array(row[double_channel_params]).reshape(1, -1)), axis=1)

# %%
# compute p_values for all clips
interictals = double_results_df.loc[double_results_df['label_desc'] == 'interictal']
double_results_df['p_value'] = double_results_df.apply(
    lambda row: (len(interictals.loc[interictals["nll"] < row['nll']])) / len(interictals), axis=1)

# %% [markdown]
# ## Visually explore results

# %%
single_results_df = add_tsne_to_df(single_results_df, single_channel_params, label_desc='test', perplexity=10.0)
# embeddings = add_tsne_to_df(double_results_df, double_channel_params)
# Out:
# C:\Users\noam\.virtualenvs\msc-WSmVxSSb\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
double_results_df = add_tsne_to_df(double_results_df, double_channel_params, label_desc='test')
# Out:
# C:\Users\noam\.virtualenvs\msc-WSmVxSSb\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
from msc.plot_utils import add_pca_to_df

double_results_df = add_pca_to_df(double_results_df, double_channel_params, label_desc='test')

# %%
embeddings = single_results_df
# embeddings = double_results_df

# %%
embeddings
# Out:
#        covar_module.data_covar_module.raw_lengthscale  \
# 1                                           -4.189489
# 2                                           -4.094140
# 4                                           -3.985386
# 5                                           -4.239130
# 7                                           -4.159550
# ...                                               ...
# 41003                                       -3.984214
# 41004                                       -4.172774
# 41005                                       -3.685556
# 41006                                       -4.087623
# 41007                                       -3.936868
#
#        covar_module.task_covar_module.covar_factor  \
# 1                                         0.206774
# 2                                         0.111852
# 4                                         0.316019
# 5                                         0.332558
# 7                                         0.163072
# ...                                            ...
# 41003                                     0.020434
# 41004                                     0.000057
# 41005                                     0.341225
# 41006                                     0.091386
# 41007                                     0.131919
#
#        covar_module.task_covar_module.raw_var label_desc  \
# 1                                   -0.281881      ictal
# 2                                   -0.456813      ictal
# 4                                   -0.084873      ictal
# 5                                   -0.212837      ictal
# 7                                   -0.399358      ictal
# ...                                       ...        ...
# 41003                               -0.698031       test
# 41004                               -1.809473       test
# 41005                               -0.201487       test
# 41006                               -0.621841       test
# 41007                               -0.521822       test
#
#                      clip_name  seizure       nll   p_value  tsne-2d-one  \
# 1        Dog_1_ictal_segment_1      NaN  1.827996  0.411035          NaN
# 2        Dog_1_ictal_segment_1      NaN  2.170897  0.552333          NaN
# 4        Dog_1_ictal_segment_1      NaN  2.237924  0.570873          NaN
# 5        Dog_1_ictal_segment_1      NaN  1.486889  0.206190          NaN
# 7        Dog_1_ictal_segment_1      NaN  1.873453  0.433612          NaN
# ...                        ...      ...       ...       ...          ...
# 41003  Dog_1_test_segment_2075     -1.0  2.679814  0.668660   -18.996357
# 41004  Dog_1_test_segment_2075     -1.0  1.977241  0.483104    41.794796
# 41005  Dog_1_test_segment_2075     -1.0  3.241851  0.730861   -66.780159
# 41006  Dog_1_test_segment_2075     -1.0  2.063448  0.515251   -27.260229
# 41007  Dog_1_test_segment_2075     -1.0  2.573882  0.653260   -41.946404
#
#        tsne-2d-two
# 1              NaN
# 2              NaN
# 4              NaN
# 5              NaN
# 7              NaN
# ...            ...
# 41003    92.212654
# 41004    46.099148
# 41005    72.186020
# 41006    78.949020
# 41007    91.338722
#
# [28128 rows x 10 columns]

# %%
sns.scatterplot(data=embeddings.sort_values('label_desc', ascending=False),
                x='tsne-2d-one', y='tsne-2d-two',
                hue_order=['ictal', 'interictal', 'test'],
                hue="label_desc", palette="muted", legend=True)
plt.suptitle("Visualizing the embeddings with t-SNE")
plt.show()

# %%
sns.scatterplot(data=embeddings.query("label_desc != 'test'"),
                x='tsne-2d-one', y='tsne-2d-two',
                hue="label_desc", palette="muted", legend=True)
plt.suptitle("Visualizing the training set")
plt.show()

# %%
sns.scatterplot(data=embeddings.query("label_desc == 'test'"),
                x='tsne-2d-one', y='tsne-2d-two',
                # hue_order=hue_order,
                hue="label_desc", palette="muted", legend=True)
plt.suptitle("2-channels Multitask Matern Params for Dog_1 Dataset")
plt.show()

# %%
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)

sns.scatterplot(data=embeddings,
                x='tsne-2d-one', y='tsne-2d-two',
                # hue_order=hue_order,
                hue="nll", palette=cmap, legend=True)
plt.suptitle("Novelty Scores")
plt.show()

# %%
cmap = sns.cubehelix_palette(rot=-.55, as_cmap=True)

sns.scatterplot(data=double_results_df,
                x='tsne-2d-one', y='tsne-2d-two',
                # hue_order=hue_order,
                hue="p_value", palette=cmap, legend=True)
plt.suptitle("Tail Area Probability (p_value)")
plt.show()

# %%
f = plt.figure()
sns.scatterplot(data=single_results_df.query("label_desc == 'test'").sample(2000),
                x=single_channel_params[0], y=single_channel_params[2],
                # hue_order=hue_order,
                hue="seizure", palette="muted", legend=True)
plt.title("Single channel embeddings")
plt.show()
f.savefig(f"{figs_base_dir}/embeddings/embeddings_single.pdf", bbox_inches='tight')

# %%
cmap = sns.color_palette("coolwarm", as_cmap=True)
cmap = sns.diverging_palette(10, 10, sep=100, center='dark', as_cmap=True)

sns.scatterplot(data=single_results_df.query("label_desc == 'test'").sample(2000),
                x=single_channel_params[0], y=single_channel_params[2],
                # hue_order=hue_order,
                hue="p_value", palette=cmap, legend=True)
plt.suptitle("Model of normal EEG")
plt.show()
plt.savefig(f"{figs_base_dir}/pvalues/pvalues_single.pdf", bbox_inches='tight')

# %%
f = plt.figure()
sns.scatterplot(data=double_results_df.query("label_desc == 'test'").sample(2000),
                x='pca-2d-one', y='pca-2d-two',
                # hue_order=hue_order,
                hue="seizure", palette="muted", legend=True)
plt.title("Double channel embeddings")
plt.show()
f.savefig(f"{figs_base_dir}/embeddings/embeddings_double.pdf", bbox_inches='tight')

# %%
sns.scatterplot(data=double_results_df.query("label_desc == 'test'").sample(2000),
                x='pca-2d-one', y='pca-2d-two',
                # hue_order=hue_order,
                hue="p_value", palette=cmap, legend=True)
plt.suptitle("Visualizing the Test Set\nDouble channel embeddings")
plt.show()

# %%
sns.scatterplot(data=double_results_df.query("label_desc == 'test'").sample(2000),
                x='tsne-2d-one', y='tsne-2d-two',
                # hue_order=hue_order,
                hue="seizure", palette="muted", legend=True)
plt.suptitle("Visualizing the Test Set\nDouble channel embeddings")
plt.show()

# %%
from sklearn.metrics import roc_auc_score

single_test = single_results_df.query("label_desc == 'test'")
print(roc_auc_score(single_test['seizure'], single_test['p_value']))
RocCurveDisplay.from_predictions(single_test['seizure'], single_test['p_value'])
plt.title("ROC curve from Novelty Score\nSingle-channel segments")
# Out:
# 0.8614994325084706
# Text(0.5, 1.0, 'ROC curve from Novelty Score\nSingle-channel segments')

# %%
double_test = double_results_df.query("label_desc == 'test'")
print(roc_auc_score(double_test['seizure'], double_test['p_value']))
RocCurveDisplay.from_predictions(double_test['seizure'], double_test['p_value'])
plt.title("ROC curve from Novelty score\nDouble-channel segments")
# Out:
# 0.9766318356147368
# Text(0.5, 1.0, 'ROC curve from Novelty score\nDouble-channel segments')

# %% [markdown]
# ## Evaluate SVM

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm, preprocessing
from mlxtend.plotting import plot_decision_regions

# encode labels
le = preprocessing.LabelEncoder()
le.fit(results_df.label_desc)
single_results_df["label"] = le.transform(single_results_df.label_desc)

# get all data
X = single_results_df.loc[single_results_df['label_desc'] == 'test', [single_channel_params[0], single_channel_params[2]]].sample(2000, random_state=42).to_numpy()
y = single_results_df.loc[single_results_df['label_desc'] == 'test', "seizure"].sample(2000, random_state=42).to_numpy().astype(np.int_)
y = np.where(y < 0, 0, y)

# split train, test
X_train, X_test, y_train, y_test = train_test_split(X, y)

# train a classifier
clf = svm.SVC(kernel='linear')
clf.fit(X, y)

# plot decision regions
plot_decision_regions(X, y, clf=clf, legend=2)

# add axes annotations
plt.xlabel(single_channel_params[0])
plt.ylabel(single_channel_params[2])
plt.title('SVM Decision Boundary\nSingle Channel Segments')

# add legend
L = plt.legend()
L.get_texts()[0].set_text(le.classes_[0])
L.get_texts()[1].set_text(le.classes_[1])
plt.show()
f.savefig(f"{figs_base_dir}/svm/svm.pdf", bbox_inches='tight')

# %%
import sklearn

# plot ROC curve
sklearn.metrics.RocCurveDisplay.from_estimator(clf, X_test, y_test)
plt.title("ROC curve for SVM\nSingle Channel Segments")
plt.show()

# %%
# # get all data
# X = double_results_df.loc[single_results_df['label_desc'] == 'test', double_channel_params].sample(2000, random_state=42).to_numpy()
# y = double_results_df.loc[single_results_df['label_desc'] == 'test', "seizure"].sample(2000, random_state=42).to_numpy().astype(np.int_)
# # y = np.where(y < 0, 0, y)

# # split train, test
# X_train, X_test, y_train, y_test = train_test_split(X, y)

# # train a classifier
# clf = svm.SVC(kernel='linear')
# clf.fit(X, y)

# # plot ROC curve
# sklearn.metrics.RocCurveDisplay.from_estimator(clf, X_test, y_test)
# plt.title("ROC curve for SVM\nDouble Channel Segments")
# plt.show()

# %%
from matplotlib.colors import LogNorm

f = plt.figure()
# selected label_desc parameters
X = single_results_df.loc[results_df["label_desc"] == 'interictal', [single_channel_params[0], single_channel_params[2]]].to_numpy()

# fit a Gaussian Mixture Model with two components
clf = mixture.GaussianMixture(n_components=2, covariance_type="full")
clf.fit(X)

# fit a Gaussian Mixture Model with two components
clf = mixture.GaussianMixture(n_components=2, covariance_type="full")
clf.fit(X)

# display predicted scores by the model as a contour plot
grid_size = 10.0
x = np.linspace(-grid_size, grid_size)
y = np.linspace(-grid_size, grid_size)
X, Y = np.meshgrid(x, y)
XX = np.array([X.ravel(), Y.ravel()]).T
Z = -clf.score_samples(XX)
Z = Z.reshape(X.shape)

CS = plt.contour(
    X, Y, Z, norm=LogNorm(vmin=1.0, vmax=100.0), levels=np.logspace(0, 2, 20)
)
CB = plt.colorbar(CS, shrink=0.8, extend="both")
plt.scatter(X[:, 0], X[:, 1], 0.8)

# add axes annotations
plt.xlabel(single_channel_params[0])
plt.ylabel(single_channel_params[2])

# add title
plt.title("Negative log-likelihood")
plt.axis("tight")
plt.show()
f.savefig(f"{figs_base_dir}/densityestimation/gmm_density.pdf", bbox_inches='tight')

# %%
sample = single_results_df.loc[single_results_df['seizure'] == -1].sample(1)

# %%
sample.seizure
# Out:
# 31031   -1.0
# Name: seizure, dtype: float64

# %%
ictality = sample.nll.item()

# %%
label = 'interictal'

# %%
ictality
# Out:
# 4.832122919456988

# %%
interictals = single_results_df.loc[single_results_df['label_desc'] == 'interictal']
# compute proportion of interictal clips with nll less than new clip (p-value)
interictals.loc[:, "nll"].plot(kind="hist", bins=100, label="all interictal clips")
plt.vlines(ictality, 0, 2000, colors="r", label=f"new clip ({label})")
plt.legend()
plt.xlim(0, 20)
p_value = (len(interictals[interictals["nll"] < ictality]))/(len(interictals))
textstr = r'$P_{value}=%.6f$' % (p_value)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax = plt.gca()
# place a text box in upper right in axes coords
ax.text(0.6, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', horizontalalignment='left',bbox=props)


plt.title("EEG Clip Novelty Measurement")
print(f"{p_value=}")
# Out:
# p_value=0.8486842105263158
