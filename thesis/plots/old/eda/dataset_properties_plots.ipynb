# %% [markdown]
# ## Dataset Exploration Plots

# %%
# %load_ext autoreload
# %autoreload 2

from scripts.pp.explore.plot_patient_recording_length_histogram import plot_patient_recording_length_histogram
from scripts.pp.explore.plot_seizure_count_histogram import plot_seizure_count_histogram
from msc.dataset.dataset import get_seizures_index_df, get_data_index_df

# these methods rely on the config file
seizures_index_df = get_seizures_index_df()
data_index_df = get_data_index_df()

plot_patient_recording_length_histogram(data_index_df)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_seizure_count_histogram(seizures_index_df)
